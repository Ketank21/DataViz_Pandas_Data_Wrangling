# %% [markdown]
# # Data Wrangling and Data Visualization to explore the Gapminder data on Life expentency and Fertility rate in different coutnries

# %% [markdown]
# Data: https://www.gapminder.org/data/ <br/>
# Life Expectency data: https://www.gapminder.org/data/documentation/gd004/ <br/>
# Total Fertility rate: https://www.gapminder.org/data/documentation/gd008/ <br/>
# FREE DATA FROM WORLD BANK VIA GAPMINDER.ORG, CC-BY LICENSE

# %% [markdown]
# ## 1) Import libraries for data wrangling and data visualization

# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
#pip install imageio

# %%
import imageio

# %% [markdown]
# ## 2) Import the data using pandas

# %% [markdown]
#  #### Using index_col  = 0 implies that we want use the first column as the index for the dataframe

# %%
df_fert=pd.read_csv('Prj_Data/gapminder_total_fertility.csv',index_col=0)

# %%
df_fert.head(5)
# Out:
#                        1800  1801  1802  1803  1804  1805  1806  1807  1808  \
# Total fertility rate
# Abkhazia                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#                        1809  ...  2006  2007  2008  2009  2010  2011  2012  \
# Total fertility rate         ...
# Abkhazia                NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan            7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14
# Akrotiri and Dhekelia   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76
# Algeria                6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82
#
# ...

# %%
df_LE=pd.read_excel('Prj_Data/gapminder_lifeexpectancy.xlsx',sheet_name='Data',index_col=0)

# %%
df_LE.shape #  returns a tuple of rows and columsn in the dataframe
# Out:
# (260, 217)

# %%
df_pop=pd.read_excel('Prj_Data/gapminder_population.xlsx',sheet_name='Data',index_col=0)

# %%
df_pop.index
# Out:
# Index(['Abkhazia', 'Afghanistan', 'Akrotiri and Dhekelia', 'Albania',
#        'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla',
#        'Antigua and Barbuda',
#        ...
#        'British Indian Ocean Territory', 'Clipperton',
#        'French Southern and Antarctic Lands', 'Gaza Strip',
#        'Heard and McDonald Islands', 'Northern Marianas',
#        'South Georgia and the South Sandwich Islands',
#        'US Minor Outlying Islands', 'Virgin Islands', 'West Bank'],
#       dtype='object', name='Total population', length=275)

# %%
df_cont=pd.read_csv('Prj_Data/continents.csv',sep=';')

# %%
df_cont.head()
# Out:
#   continent   country
# 0    Africa   Algeria
# 1    Africa    Angola
# 2    Africa     Benin
# 3    Africa  Botswana
# 4    Africa   Burkina

# %%
#cd '/home/ketankm/github/DataViz_Pandas_Data_Wrangling'

# %% [markdown]
# Check the shape of all data, imported as dataframes

# %%
print(f"df_fert.shape -> {df_fert.shape}, \ndf_LE.shape -> {df_LE.shape}, \ndf_pop.shape -> {df_pop.shape}, \ndf_cont.shape -> {df_cont.shape}" )
# Out:
# df_fert.shape -> (260, 216),
# df_LE.shape -> (260, 217),
# df_pop.shape -> (275, 91),
# df_cont.shape -> (194, 2)

# %%
# check the extra rows for the population data
len(df_pop.index)
# Out:
# 275

# %% [markdown]
# ## 3) Examine the column data

# %%
df_fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
df_LE.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %%
df_pop.columns
# Out:
# Index([         1800,          1810,          1820,          1830,
#                 1840,          1850,          1860,          1870,
#                 1880,          1890,          1900,          1910,
#                 1920,          1930,          1940,          1950,
#                 1951,          1952,          1953,          1954,
#                 1955,          1956,          1957,          1958,
#                 1959,          1960,          1961,          1962,
#                 1963,          1964,          1965,          1966,
#                 1967,          1968,          1969,          1970,
#                 1971,          1972,          1973,          1974,
#                 1975,          1976,          1977,          1978,
#                 1979,          1980,          1981,          1982,
#                 1983,          1984,          1985,          1986,
#                 1987,          1988,          1989,          1990,
# ...

# %%
df_pop.drop(['Unnamed: 82', 'Unnamed: 83', 'Unnamed: 84','Unnamed: 85', 'Unnamed: 86', 'Unnamed: 87', 'Unnamed: 88','Unnamed: 89', 'Unnamed: 90', 'Unnamed: 91'],axis=1,inplace=True)
df_pop.head()
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 410445.0   423591.0   438671.0   457234.0   478227.0
# Algeria                2503218.0  2595056.0  2713079.0  2880355.0  3082721.0
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
# Albania                 506889.0   552800.0   610036.0   672544.0   741688.0
# Algeria                3299305.0  3536468.0  3811028.0  4143163.0  4525691.0
#
# ...

# %%
df_fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %% [markdown]
# #### Reset the column headers as integers,since the indexes contain the countries

# %%
df_pop.columns =df_pop.columns.astype(int)

# %%
df_fert.columns =df_fert.columns.astype(int)

# %%
df_LE.columns = df_LE.columns.astype(int)

# %%
df_cont.columns
# Out:
# Index(['continent', 'country'], dtype='object')

# %% [markdown]
# #### Reset the indexes to extract the column with countries and change the column name to country (instead of Life expectency, fertility, Total Population)

# %%
df_fert.reset_index(inplace = True)

# %%
df_fert.columns
# Out:
# Index(['Total fertility rate',                   1800,                   1801,
#                          1802,                   1803,                   1804,
#                          1805,                   1806,                   1807,
#                          1808,
#        ...
#                          2006,                   2007,                   2008,
#                          2009,                   2010,                   2011,
#                          2012,                   2013,                   2014,
#                          2015],
#       dtype='object', length=217)

# %%
df_LE.reset_index(inplace= True)
df_LE.head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %%
df_pop.reset_index(inplace=True)
df_pop.head()
# Out:
#         Total population       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...        2006  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...  25183615.0
# 2        NaN        NaN        NaN        NaN        NaN  ...     15700.0
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...   3050741.0
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...  33749328.0
#
#          2007        2008        2009        2010        2011        2012  \
# ...

# %% [markdown]
# #### Renaming the index as country to enable merging

# %%
df_fert.rename(columns ={'Total fertility rate':'country'}, inplace = True)
df_fert.head()
# Out:
#                  country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0               Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2  Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#    1808  ...  2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  7.00  ...  6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# 2   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  4.60  ...  1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
# 4  6.99  ...  2.58  2.66  2.73  2.78  2.82  2.83  2.82  2.80  2.76  2.71
#
# [5 rows x 217 columns]

# %%
df_pop.rename(columns={'Total population':'country'},inplace= True)
df_pop.head()
# Out:
#                  country       1800       1810       1820       1830  \
# 0               Abkhazia        NaN        NaN        NaN        NaN
# 1            Afghanistan  3280000.0  3280000.0  3323519.0  3448982.0
# 2  Akrotiri and Dhekelia        NaN        NaN        NaN        NaN
# 3                Albania   410445.0   423591.0   438671.0   457234.0
# 4                Algeria  2503218.0  2595056.0  2713079.0  2880355.0
#
#         1840       1850       1860       1870       1880  ...        2006  \
# 0        NaN        NaN        NaN        NaN        NaN  ...         NaN
# 1  3625022.0  3810047.0  3973968.0  4169690.0  4419695.0  ...  25183615.0
# 2        NaN        NaN        NaN        NaN        NaN  ...     15700.0
# 3   478227.0   506889.0   552800.0   610036.0   672544.0  ...   3050741.0
# 4  3082721.0  3299305.0  3536468.0  3811028.0  4143163.0  ...  33749328.0
#
#          2007        2008        2009        2010        2011        2012  \
# ...

# %%
df_LE.rename(columns ={'Life expectancy':'country'},inplace = True)
df_LE.head()
# Out:
#                  country   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...  2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...  52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...  76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...  75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# 4  76.50
#
# ...

# %% [markdown]
# ## 4) Melting dataframes into long formats

# %%
df_fert =df_fert.melt(id_vars=['country'],
                     var_name='year',
                     value_name ='fertility_rate')
df_fert.head()
# Out:
#                  country  year  fertility_rate
# 0               Abkhazia  1800             NaN
# 1            Afghanistan  1800            7.00
# 2  Akrotiri and Dhekelia  1800             NaN
# 3                Albania  1800            4.60
# 4                Algeria  1800            6.99

# %%
df_LE =df_LE.melt(id_vars=['country'],
                     var_name='year',
                     value_name ='life_expectancy')
df_LE.head()
# Out:
#                  country  year  life_expectancy
# 0               Abkhazia  1800              NaN
# 1            Afghanistan  1800            28.21
# 2  Akrotiri and Dhekelia  1800              NaN
# 3                Albania  1800            35.40
# 4                Algeria  1800            28.82

# %%
df_pop =df_pop.melt(id_vars=['country'],
                     var_name='year',
                     value_name ='total_population')
df_pop.head()
# Out:
#                  country  year  total_population
# 0               Abkhazia  1800               NaN
# 1            Afghanistan  1800         3280000.0
# 2  Akrotiri and Dhekelia  1800               NaN
# 3                Albania  1800          410445.0
# 4                Algeria  1800         2503218.0

# %% [markdown]
# ## 5) Merge Dataframes

# %%
df_gapminder_merged =pd.merge(df_fert,df_LE,on =['country','year'],how ='inner')
df_gapminder_merged.head()
# Out:
#                  country  year  fertility_rate  life_expectancy
# 0               Abkhazia  1800             NaN              NaN
# 1            Afghanistan  1800            7.00            28.21
# 2  Akrotiri and Dhekelia  1800             NaN              NaN
# 3                Albania  1800            4.60            35.40
# 4                Algeria  1800            6.99            28.82

# %%
df_gapminder_merged =pd.merge(df_gapminder_merged,df_pop,on =['country','year'],how = 'left')
df_gapminder_merged.head()
# Out:
#                  country  year  fertility_rate  life_expectancy  \
# 0               Abkhazia  1800             NaN              NaN
# 1            Afghanistan  1800            7.00            28.21
# 2  Akrotiri and Dhekelia  1800             NaN              NaN
# 3                Albania  1800            4.60            35.40
# 4                Algeria  1800            6.99            28.82
#
#    total_population
# 0               NaN
# 1         3280000.0
# 2               NaN
# 3          410445.0
# 4         2503218.0

# %%
df_gapminder_merged = pd.merge(df_gapminder_merged,df_cont,on ='country',how='left')
df_gapminder_merged.head()
# Out:
#                  country  year  fertility_rate  life_expectancy  \
# 0               Abkhazia  1800             NaN              NaN
# 1            Afghanistan  1800            7.00            28.21
# 2  Akrotiri and Dhekelia  1800             NaN              NaN
# 3                Albania  1800            4.60            35.40
# 4                Algeria  1800            6.99            28.82
#
#    total_population continent
# 0               NaN       NaN
# 1         3280000.0      Asia
# 2               NaN       NaN
# 3          410445.0    Europe
# 4         2503218.0    Africa

# %%
df_gapminder_merged['continent'].unique() # identifying unwanted entries in the continent column
# Out:
# array([nan, 'Asia', 'Europe', 'Africa', 'North America', 'South America',
#        'Australia and Oceania'], dtype=object)

# %%
df_gapminder_explore_continent=df_gapminder_merged[df_gapminder_merged['continent'].isna() == True]

# %%
df_gapminder_explore_continent_hk = df_gapminder_explore_continent[df_gapminder_explore_continent['country'] =="North Korea" ]
df_gapminder_explore_continent_hk
# Out:
#            country  year  fertility_rate  life_expectancy  total_population  \
# 116    North Korea  1800            6.10             26.0         4345000.0
# 376    North Korea  1801            6.10             26.0               NaN
# 636    North Korea  1802            6.10             26.0               NaN
# 896    North Korea  1803            6.10             26.0               NaN
# 1156   North Korea  1804            6.10             26.0               NaN
# ...            ...   ...             ...              ...               ...
# 54976  North Korea  2011            2.00             71.4        24631359.0
# 55236  North Korea  2012            2.00             71.6        24763353.0
# 55496  North Korea  2013            1.99             71.8        24895705.0
# 55756  North Korea  2014            1.98             71.9        25026772.0
# 56016  North Korea  2015            1.97             72.1        25155317.0
#
#       continent
# 116         NaN
# 376         NaN
# ...

# %%
x= df_gapminder_explore_continent['country']

# %%
country_counts ={}
for entry in x:
    if entry not in country_counts:
        country_counts[entry] = 0
    country_counts[entry] = country_counts[entry] + 1

    
#country_counts # number entries for countries not attributed to continents in the dastaframe

# %%
#df_gapminder_merged.dropna(subset =['continent']) # to drop columns with NaN entries but we need to be careful 
#since the coutnry might be part of a continent over the span of 200 years

# %%
df_gapminder_merged_cleaned = df_gapminder_merged.drop(df_gapminder_merged[df_gapminder_merged['continent'] == 'NaN'].index)
df_gapminder_merged_cleaned.head()
# Out:
#                  country  year  fertility_rate  life_expectancy  \
# 0               Abkhazia  1800             NaN              NaN
# 1            Afghanistan  1800            7.00            28.21
# 2  Akrotiri and Dhekelia  1800             NaN              NaN
# 3                Albania  1800            4.60            35.40
# 4                Algeria  1800            6.99            28.82
#
#    total_population continent
# 0               NaN       NaN
# 1         3280000.0      Asia
# 2               NaN       NaN
# 3          410445.0    Europe
# 4         2503218.0    Africa

# %% [markdown]
# ## Plotting Graphs from the data frame

# %%
#https://www.python-graph-gallery.com/bubble-plot/       #used this a lot!!!
import seaborn as sns
import matplotlib.pyplot as plt
for year in range(1960,2015):

    plt.figure(figsize=(10,6))
    df_subset=df_gapminder_merged.loc[df_gapminder_merged['year']==year]
    sns.scatterplot(x='life_expectancy',y='fertility_rate',
                    data=df_subset,size="total_population",
                    alpha=0.6,legend="brief",sizes=(20,2000),
                    hue='continent')
    s = str(year)
    plt.title('Fertility rate vs Life Expectency from 1960 to 2015',fontsize=14)
    plt.xlabel("Life expectancy / years",loc= "right",fontsize= 12)
    plt.ylabel("Fertility rate / %", loc="top",fontsize=12)
    plt.text(30,9,s,fontsize = 16)#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.text.html
    plt.axis(xmin=20,xmax =100,ymin=0,ymax=10)
    plt.legend(loc=(0.85,0.5))
    sns.despine()
    plt.savefig("Graphs/lifeexp_"+ str(year) +".png")
    year =year + 1
    plt.close()

# %%
images=[]

for i in range(1960,2015):
    filename ='Graphs/lifeexp_{}.png'.format(i)
    images.append(imageio.imread(filename))
imageio.mimsave('output.gif',images,fps=5)
